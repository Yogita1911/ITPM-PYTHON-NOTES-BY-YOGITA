# %% [markdown]
# ## IF else Statement:
#
# If else statements are dicision making statements. (check for True or False)
#
# When if is True then if block gets executed otherwise else block will be executed
#
# If & elif can not be empty, else statement can be empty
#
# Syntax : if (condition):

# %%
#c lang
if condtion ;
{
    stat ;
}

# %%
#syntax :
if condition/(condition) : 
    statment
#syntax :
if condition :  
    statments #exc
    statments
else : 
    statment

# %%
Correct ways:
    if
    if elif
    if if    >> multiple ifs
    if elif elif  >> multiple elifs following an if
    if elif else  >> elif in between if & else
    if elif elif else >> multiple elifs in b/w if & else
    if else
    
    
Incorrect Ways:
    elif
    elif elif
    else
    else if
    else elif
    if else elif
    if else else

# %% [markdown]
# 1. Write a program to check if a number is positive or negative.
# 2. Write a program to check whether a number is odd or even.
# 3. Write a program to determine if a given year is a leap year or not.
# 4. Write a program to find the greater of two numbers.
# 5. Write a program to check if a student has passed or failed based on a mark of 40.
# 6. Write a program to check if a person is eligible to vote (age >= 18).
# 7. Write a program to classify a number as positive, negative, or zero.
# 8. Write a program to assign a grade based on the score provided by the user.
# 9. Write a program to check if a number is divisible by both 3 and 5.
# 10. Write a program to find the largest of three numbers.
# 11. Write a program to check if three given sides can form a triangle.
# 12. Write a program to check if a character entered is an alphabet or not.
# 13. Write a program to check if an entered character is a vowel or consonant.
# 14. Write a program to calculate a discount based on the purchase amount (e.g., 10% for purchases above $100).
# 15. Write a program to perform addition, subtraction, multiplication, or division based on the user’s choice.

# %%
#1.WAP TO CHECK GIVEN NUMBER IS + , - ,0.
X=int(input("Enter a number"))
if X>0 :
    print("X is positive")
elif X<0 :
    print("X is Negative")
else :
    print("X is Zero")

# %%
#WAP to print given number is evev or odd take input from user
x = int(input("Enter a number :"))     #x = 45
if x%2==0 :  # if condition is true 45%2==1  False
  print("x is Even")   #than remaining stat print
else :  # if condition of if sata is not true then directly jump to else
  print("x is odd")

# %%
#you can add multiple statments inside if or else block.
if x%2==0 :  
    print("x is Even") #indented block not given that why throw an error
    print("x1 is Even")   
else :
    print("x is odd")

# %%
x=7
if x%2==0 :  # if condition is false 
  print("x is Even") 
else :
    print("x is odd")  #than remaining stat prin

# %%
 #WAP TO CHECK GIVEN IS GREATER THEN 10 OR NOT
x= int(input("Enter a number:"))
if x>=10 :      # condition full fill thats why if block ex
    print("x is greater than 10 or equal ")
else :
    print("x is less than 10")

# %%
#3.WAP TO PRINT GIVEN NUMBER IS GREATER THAN 50 OR NOT
Number =int(input("Enter a number:"))   # taking user input
if Number>50 :
    print("Number is greater than 10")
else :
    print("Number is not greater than 10")

# %%
# 2. Check whether a number is odd or even
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")

# %%
# 3. Determine if a given year is a leap year
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("The year is a leap year.")
else:
    print("The year is not a leap year.")

# %%
# 4. Find the greater of two numbers
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
if a > b:
    print(f"The greater number is {a}.")
else:
    print(f"The greater number is {b}.")

# %%
# 5. Check if a student has passed or failed
marks = float(input("Enter the marks: "))
if marks >= 40:
    print("The student has passed.")
else:
    print("The student has failed.")

# %%
# 6. Check if a person is eligible to vote
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")

# %%
# 7. Classify a number as positive, negative, or zero
number = float(input("Enter a number: "))
if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# %%
# 8. Assign a grade based on the score
score = float(input("Enter the score: "))
if score >= 91 and score <= 100:
    print("Grade: A")
elif score >= 81 and score <= 90:
    print("Grade: B")
elif score >= 71 and score <= 80:
    print("Grade: C")
elif score >= 61 and score <= 70:
    print("Grade: D")
else:
    print("Grade: F")

# %%
# 9. Check if a number is divisible by both 3 and 5
number = int(input("Enter a number: "))
if number % 3 == 0 and number % 5 == 0:
    print("The number is divisible by both 3 and 5.")
else:
    print("The number is not divisible by both 3 and 5.")

# %%
# 10. Find the largest of three numbers
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))
c = float(input("Enter the third number: "))
if a > b and a > c:
    print(f"The largest number is {a}.")
elif b > c:
    print(f"The largest number is {b}.")
else:
    print(f"The largest number is {c}.")

# %%
# 11. Check if three sides can form a triangle
a = float(input("Enter the first side: "))
b = float(input("Enter the second side: "))
c = float(input("Enter the third side: "))
if a + b > c and a + c > b and b + c > a:
    print("The sides can form a triangle.")
else:
    print("The sides cannot form a triangle.")

# %%
# 12. Check if a character entered is an alphabet
char = input("Enter a character: ")
if char.isalpha():
    print("The character is an alphabet.")
else:
    print("The character is not an alphabet.")

# %%
# 13. Check if a character is a vowel or consonant
char = input("Enter a character: ")
if char in 'aeiouAEIOU':
    print("The character is a vowel.")
elif char.isalpha():
    print("The character is a consonant.")
else:
    print("Invalid input.")

# %%
# 14. Calculate a discount based on the purchase amount
purchase_amount = float(input("Enter the purchase amount: $"))
if purchase_amount > 100:
    discount = purchase_amount * 0.10  
    final_amount = purchase_amount - discount
    print(f"You are eligible for a 10% discount!")
    print(f"Discount: ${discount:.2f}")
    print(f"Final amount after discount: ${final_amount:.2f}")
else:
    print("No discount available.")
    print(f"Total amount: ${purchase_amount:.2f}")

# %%
#14.
amount=float(input("enter amount"))
if amount>=1000 and amount<=3000:
    discount=(amount/100)*10
    print(f"discount is 10% ie.:{discount}")
elif amount>3000 and amount<=5000:
    discount=(amount/100)*20
    print(f"discount is 20% ie.:{discount}")
else:
    discount=(amount/100)*25
    print(f"discount is 25% ie.:{discount}")

# %%
# 15. Perform arithmetic operations based on user's choice
print("Choose operation: 1. Addition 2. Subtraction 3. Multiplication 4. Division")
choice = int(input("Enter your choice (1-4): "))
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))

if choice == 1:
    print(f"Result: {a + b}")
elif choice == 2:
    print(f"Result: {a - b}")
elif choice == 3:
    print(f"Result: {a * b}")
elif choice == 4:
    if b != 0:
        print(f"Result: {a / b}")
    else:
        print("Division by zero is not allowed.")
else:
    print("Invalid choice.")
