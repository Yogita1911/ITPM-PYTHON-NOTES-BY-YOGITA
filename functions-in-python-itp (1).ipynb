# %% [markdown]
# ## What is function.

# %% [markdown]
# ##### A function is a block of code which only runs when it is called.
#
# ##### You can pass data, known as parameters, into a function
#
# ##### A function can return data as a result.

# %% [markdown]
# ## Creating a Function
# #### In Python a function is defined using the def keyword:

# %%
Sytax :
    def fun_name():
        hhhdkdhlhd

# %%
#Ex1:
def my_function():                    #Create function
    print("Hello from a function")    # print somthing using function
    
my_function()                      #functtion call

# %%
#WAP TO PRINT YOUR NAME USING FUNCTION
#WAP TO PRINT YOUR ADDRESS USING FUNCTION

# %%
def name():   
    print("I AM SHUBHANGI")
name()

# %%
def address():
    print("AM FROM PUNE")
address()
# Out:
# AM FROM PUNE

# %% [markdown]
# ## Calling a Function
# #### To call a function, use the function name followed by parenthesis:
# #### Syntax : function_name ()

# %%
my_function()

# %% [markdown]
# ## Arguments
# #### Information can be passed into functions as arguments.
#
# #### Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# #### The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:

# %%
def my_function(fname):     # here fname is single argument
    print(fname)            # print function is use to print value of argument

my_function("YASH")        # function call with argument values

# %%
def python_student(name): # directly pass arugemnts during function creation
    print(name)

# %%
python_student("vilkas")

# %%
my_function("Shubhangi")

# %%
def my_function(fname,lname):  # here we pass multiple arguments
    print(fname+ ' '+lname)

my_function("shubham","patil")

# %%
def Student_full(name,last):
    print(name,last)
Student_full("Isha","patil")

# %%
 def Student_full(name,middle,last):
    print(name,middle,last)
Student_full("Isha","xyz","patil")

# %%
#Example
def my_function(child3, child2, child1):
    print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")

# %%
def full_name(fname,mname,lname):
      print("last name : " + lname)

full_name(fname="somesh" , mname ="sanjay",lname="patil")

# %% [markdown]
# ## Arbitrary Arguments, *args
# ##### If you do not know how many arguments that will be passed into your function, add a * before the parameter name in the function definition.
#
# ##### This way the function will receive a tuple of arguments, and can access the items accordingly:

# %%
def my_function(*kids):
    print(kids)

my_function("sonu", "monu", "chiku")

# %%
def my_function(*kids):
    print(kids)

my_function("sonu", "monu")

# %%
def add(a,b):
    return a+b
add(3,4)
# Out:
# 7

# %%
def add(a,b):
    return a+b
add(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 def add(a,b):
#       2     return a+b
# ----> 3 add(3,4,5)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(*num):
   return sum(num)
add(2,3)
add(2,3,4)
add(3,4,5,6)
# Out:
# 9

# %%
def my_function(fname,lname):     # here fname is single argument
    print(fname , lname)            # print function is use to print value of argument

my_function("YASH")

# %%
#WAP to print name of students using arbitry argument
def student(*name):
    print(name)

student("Dhananjay","somesh")

# %%
def numbers(*num):
    print(num)
numbers(1,2,3,4,5)

# %%
def numbers(*num):
    print(num[3])
numbers(1,2,3,4,5)

# %%
def my_function(*kids):
    print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")

# %%
def my_function(*kids):
    print( kids[1])

my_function("Emil", "Tobias", "Linus")

# %%
def display_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

display_info(name="Alice", age=25, city="New York")

# %% [markdown]
# ## Keyword Arguments
# #### You can also send arguments with the key = value syntax.
#
# #### This way the order of the arguments does not matter.

# %%
def my_function(child3, child2, child1):       # argument name
    print("The youngest child is " + child3)

my_function(child1 = "Emil", child2 = "Tobias", child3 = "Linus")

# %%
def numbers(a,b,c):
    return a,b,c

numbers(b=5,c=3,a=2)
# Out:
# (2, 5, 3)

# %%
def full_name(fname,mname,lname)         # ardument declear
     print(fname+ ''+mname+'' +lname)

full_name(fname="sayli",mname="dnyanoba",lname="narayanpure")    # values pass using keyword

# %%
def full_name(fname,mname,lname):        
     print(fname+ ' '+mname+' ' +lname)
   
full_name(fname="sayli",lname="narayanpure",mname="dnyanoba") #order doesn't matter

# %%
def numbers(x,y,z):
    print(x , y,z)

numbers(x=1,z=3,y=2)

# %%
def numbers(x,y,z):
    print(x , y,z)
numbers(1,2,3)     # number of arguments !== pass values of argument

# %% [markdown]
# ## Default Parameter Value
# #### The following example shows how to use a default parameter value.
#
# #### If we call the function without argument, it uses the default value:

# %%
def my_function(country = "Norway"):
    print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()       #
my_function("Brazil")
# Out:
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil

# %%
def address(address="pune"):    #d value = "pune"
     print("stduent address :"+address )
address()       #
address("mumbai")

# %%
def address():
    print("print address")
address()

# %% [markdown]
# ## Types of Functions in Python
# #### Python supports various types of functions, each serving different purposes in programming. Here are the main types of functions in Python, along with examples:
#
# ### 1. Built-in Functions
# ##### These functions are pre-defined in Python and can be used directly without any further declaration.
#
# ### 2. User-defined Functions
# ##### These are functions that users create to perform specific tasks.

# %%
# Using the built-in len() function

my_list = [1, 2, 3, 4, 5]

print(len(my_list))  # Output: 5

# %%
#WAP TO Perform any 10 bulit_in function.
#1.Min() 2.Max() 3.sum() 4.index() 5.count() 6.append() 7.set() 8.join() 9.tuple() 10.length() 11.extend() 12.add() 13.remove()
#14.clear() 15.copy() 16.pop() 17.delete() 18.slice()
#20.reverse() 21.insert() 22.startwith() 23.concate() 24.multiple() 25.split()

# %%
#using user defined functions
#WAP to add two numbers using
def add_numbers(a, b):   

    return a + b

result = add_numbers(3, 5)

print(result)  # Output: 8

# %% [markdown]
# ### input()

# %%
name = input("enter a name")
print (name)

# %%
number = int(input("enter a number"))
print(number)

# %% [markdown]
# ### DELETE FUNCTION

# %%
del function_name

# %%
def student(*name):
    print(name)

student("Dhananjay","somesh")

# %%
del student

# %%
student()

# %%
def add_numbers(a, b):

    return a + b

result = add_numbers(3, 5)

print(result)  # Output: 8

# %%
# Example 
#1.WAP TO PRINT ADDITION OF TWO NUMBWER USING FUNCTION
#2.WAP TO PRINT MULTIPLICATION OF TWO NUMBWER USING FUNCTION.
#3.WAP TO CHEACK GIVEN NUMBER IS EVEN OR ODD.
#4.WAP TO CHEACK GIVEN YEAR IS LEAP OR NOT.
#5.WAP TO FIND MAX OF THREE NUMBERS.
#6.Write a function that takes a list of numbers and returns the sum.
#7.Write a function to check if a string is a palindrome.
#8.Write a function that returns the factorial of a number.

# %%
#1.WAP TO PRINT ADDITION OF TWO NUMBWER USING FUNCTION
def addition_numbers(a,b):   # create function to perform addition of two numbers(a,b)
    return a+b

addition_numbers(3,5)    #
# Out:
# 8

# %%
#2.WAP to perform additon of 3 numbers.

# %%
#3.WAP TO PRINT MULTIPLICATION OF Three NUMBWER USING FUNCTION.
def multiplication_numbers(a,b,c):
          return a*b*c
multiplication_numbers(2,3,4)

# %%
#4.WAP TO PRINT substraction OF TWO NUMBWER USING FUNCTION.
#5.WAP TO PRINT DIVISION OF TWO NUMBWER USING FUNCTION.......DO THIS

# %%
#6.WAP TO CHEACK GIVEN NUMBER IS EVEN OR ODD using function.
def check_even_odd(num):
    if num%2==0:
        return "even"
    else :
        return "odd"

print(check_even_odd(10))
print(check_even_odd(5))
# Out:
# even
# odd

# %%
# 7.WAP TO CHEACK GIVEN NUMBER IS + or - using function.
def check_positive_negative(num):
    if num>0:
       return "Num is positive"
    else:
       return "Num is negative"
print(check_positive_negative(5))
print(check_positive_negative(-5))
# Out:
# Num is positive
# Num is negative

# %%
#8.WAP TO CHEACK GIVEN YEAR IS LEAP OR NOT
def leap_year(year):
    if (year%4==0 and year%100!=0):
        return "This is leap year"
    else :
        return "This is not leap year"
print(leap_year(2004))
print(leap_year(2013))
# Out:
# This is leap year
# This is not leap year

# %%
def leap_year(year):
    if (year%400==0):
        return "This is leap year"
    else :
        return "This is not leap year"
print(leap_year(2004))
print(leap_year(2013))
# Out:
# This is not leap year
# This is not leap year

# %%
#9.WAP TO FIND MAX OF THREE NUMBERS.
def max_number(a,b,c):
    if (a>b and a>c):
        print(f"{a} is max")
    elif(b>a and b>c):
        print(f"{b}is max")
    elif (c>a and c>b):
        print(f"{c} is max")
    else :
        print("invalid input")
print(max_number(10,20,30))
# Out:
# 30 is max
# None

# %%
def max_number(a,b,c):
    return max(a,b,c)
print(max_number(10,20,30))
# Out:
# 30

# %%
#10.Write a function that takes a list of numbers and returns the sum.
def sum_number(a,b):
    return a+b
sum_number(4,5)
# Out:
# 9

# %%
#11.Write a function that takes a list of numbers and returns the sum.
# print(sum_number([4,5,6,7])
def sum_numbers(number):
    return sum(number)

print(sum_numbers([1,2,3,4,5]))
# Out:
# 15

# %%
#12.Write a function to check if a string is a palindrome.
def palindram(s):
     return s == s[::-1]    
print(palindram("pop"))
#print(palindram("hello"))
# Out:
# True
# False

# %%
#13.Write a function to find factorial of given number.
def factorial(n):
    if n==1:
        return 1
    else :                              # n=5 (1*2*3*4*5)
        return n * factorial(n-1)       # return = n*(n-1)=5*4 =20 
                                        # 
    

print(factorial(5))
# Out:
# 120

# %%
# 14.Write a function to check given number is prime or not.
# 15.write a function to check max and min marks of students.
