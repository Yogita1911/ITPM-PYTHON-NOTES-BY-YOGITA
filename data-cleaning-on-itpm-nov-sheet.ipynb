# %% [markdown]
# DATA CLEANING :
# 1.read_csv()
# 2.head()
# 3.tail()
# 4.info()
# 5.describe()
# 6.shape
# 7.isnull()
# 8.isnull().sum()
# 9.rename()
# 10.drop()
# 11.specific index
# 12.dropna()
# 13.sum()
# 14.mean()
# 15.max()
# 16.min()
# 17.fillna()
# 18.drop_duplicate()
# 19.duplicated()
# 20.count()
# 21.read_excel()
# 22.read_json()

# %%
import pandas as pd

# %%
df = pd.read_excel("/kaggle/input/itpm-nov1/Itpm_nov.xlsx")
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %%
df.tail()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Candidate Full Name         37 non-null     object
#  1   Admission Date              27 non-null     datetime64[ns]
#  2   Course Name                 37 non-null     object
#  3   Domain                      33 non-null     object
#  4   Skill Possessed             37 non-null     object
#  5   10th Percentage             28 non-null     float64
#  6   10th YOP                    37 non-null     int64
#  7   12th Percentage             35 non-null     float64
#  8   12th YOP                    37 non-null     int64
#  9   Diploma Percentage          3 non-null      float64
#  10  Diploma YOP                 3 non-null      float64
#  11  Graduation                  37 non-null     object
#  12  Graduation Percentage       37 non-null     object
# ...

# %%
df.isnull()
# Out:
#     Candidate Full Name  Admission Date  Course Name  Domain  Skill Possessed  \
# 0                 False           False        False   False            False
# 1                 False           False        False   False            False
# 2                 False           False        False   False            False
# 3                 False           False        False    True            False
# 4                 False            True        False   False            False
# 5                 False           False        False   False            False
# 6                 False           False        False    True            False
# 7                 False           False        False   False            False
# 8                 False           False        False   False            False
# 9                 False           False        False    True            False
# 10                False           False        False   False            False
# ...

# %%
df.isnull().sum()
# Out:
# Candidate Full Name            0
# Admission Date                10
# Course Name                    0
# Domain                         4
# Skill Possessed                0
# 10th Percentage                9
# 10th YOP                       0
# 12th Percentage                2
# 12th YOP                       0
# Diploma Percentage            34
# Diploma YOP                   34
# Graduation                     0
# Graduation Percentage          0
# Graduation YOP                 0
# Post Graduation               32
# Post Graduation Percentage    33
# Post Graduation YOP           33
# Current City                   0
# Candidate Status               0
# Final MOCK                     0
# Communication Remark           0
# Technical Remark               4
# Resume                         2
# dtype: int64

# %%
df.describe()
# Out:
#             Admission Date  10th Percentage     10th YOP  12th Percentage  \
# count                   27        28.000000    37.000000        35.000000
# mean   2024-08-04 14:13:20        74.009643  2016.027027        63.544286
# min    2024-01-07 00:00:00         9.470000  2005.000000         7.830000
# 25%    2024-07-27 00:00:00        71.250000  2016.000000        59.080000
# 50%    2024-08-26 00:00:00        79.300000  2018.000000        65.000000
# 75%    2024-09-09 12:00:00        85.150000  2018.000000        70.450000
# max    2024-09-20 00:00:00        94.200000  2020.000000        97.610000
# std                    NaN        19.839839     3.961527        17.395518
#
#           12th YOP  Diploma Percentage  Diploma YOP  Graduation YOP  \
# count    37.000000                 3.0     3.000000       37.000000
# mean   2018.054054                69.0  2017.333333     2022.135135
# min    2008.000000                65.0  2014.000000     2012.000000
# ...

# %%
df.shape
# Out:
# (37, 23)

# %%
df.drop(columns=['Candidate Status'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Candidate Full Name         37 non-null     object
#  1   Admission Date              27 non-null     datetime64[ns]
#  2   Course Name                 37 non-null     object
#  3   Domain                      33 non-null     object
#  4   Skill Possessed             37 non-null     object
#  5   10th Percentage             28 non-null     float64
#  6   10th YOP                    37 non-null     int64
#  7   12th Percentage             35 non-null     float64
#  8   12th YOP                    37 non-null     int64
#  9   Diploma Percentage          3 non-null      float64
#  10  Diploma YOP                 3 non-null      float64
#  11  Graduation                  37 non-null     object
#  12  Graduation Percentage       37 non-null     object
# ...

# %%
df.rename(columns ={'Technical Remark':'TR'},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Candidate Full Name         37 non-null     object
#  1   Admission Date              27 non-null     datetime64[ns]
#  2   Course Name                 37 non-null     object
#  3   Domain                      33 non-null     object
#  4   Skill Possessed             37 non-null     object
#  5   10th Percentage             28 non-null     float64
#  6   10th YOP                    37 non-null     int64
#  7   12th Percentage             35 non-null     float64
#  8   12th YOP                    37 non-null     int64
#  9   Diploma Percentage          3 non-null      float64
#  10  Diploma YOP                 3 non-null      float64
#  11  Graduation                  37 non-null     object
#  12  Graduation Percentage       37 non-null     object
# ...

# %%
df.loc[1]
# Out:
# Candidate Full Name                           Kumail Mehter
# Admission Date                          2024-08-14 00:00:00
# Course Name                                            ITPM
# Domain                                       Data Analytics
# Skill Possessed               C,UI,Sql,DataAnalytics,Python
# 10th Percentage                                         NaN
# 10th YOP                                               2019
# 12th Percentage                                        82.5
# 12th YOP                                               2021
# Diploma Percentage                                      NaN
# Diploma YOP                                             NaN
# Graduation                                    Bsc Computers
# Graduation Percentage             Above 60% OR CGPA above 6
# Graduation YOP                                         2024
# Post Graduation                                         NaN
# Post Graduation Percentage                              NaN
# ...

# %%
df.isnull().sum()
# Out:
# Candidate Full Name            0
# Admission Date                10
# Course Name                    0
# Domain                         4
# Skill Possessed                0
# 10th Percentage                9
# 10th YOP                       0
# 12th Percentage                2
# 12th YOP                       0
# Diploma Percentage            34
# Diploma YOP                   34
# Graduation                     0
# Graduation Percentage          0
# Graduation YOP                 0
# Post Graduation               32
# Post Graduation Percentage    33
# Post Graduation YOP           33
# Current City                   0
# Final MOCK                     0
# Communication Remark           0
# TR                             4
# dtype: int64

# %%
df2 = df.fillna(12)
df2.head()
# Out:
#    Candidate Full Name       Admission Date  Course Name  \
# 0        Vikas  Ghadge  2024-01-07 00:00:00         ITPM
# 1        Kumail Mehter  2024-08-14 00:00:00         ITPM
# 2      Avantika Jadhav  2024-09-20 00:00:00         ITPM
# 3     Chaitanya Sawant  2024-08-26 00:00:00         ITPM
# 4         Nupur Pandya                   12         ITPM
# 5       Kanchan Malode  2024-09-11 00:00:00         ITPM
# 6          Divya Borse  2024-09-02 00:00:00         ITPM
# 7           Isha Nikam  2024-08-28 00:00:00         ITPM
# 8   Yadnyesh Chaudhari  2024-09-20 00:00:00         ITPM
# 9         Priya Kamble  2024-09-14 00:00:00         ITPM
# 10        Mayur Sabgar  2024-08-01 00:00:00         ITPM
# 11    Snehal Sherikar                    12         ITPM
# 12        Akash Sonone                   12         ITPM
# 13     Sakshi  Vidhate  2024-09-06 00:00:00         ITPM
# 14     Sanjay Wankhade  2024-08-30 00:00:00         ITPM
# ...

# %%
df2.isnull().sum()
# Out:
# Candidate Full Name           0
# Admission Date                0
# Course Name                   0
# Domain                        0
# Skill Possessed               0
# 10th Percentage               0
# 10th YOP                      0
# 12th Percentage               0
# 12th YOP                      0
# Diploma Percentage            0
# Diploma YOP                   0
# Graduation                    0
# Graduation Percentage         0
# Graduation YOP                0
# Post Graduation               0
# Post Graduation Percentage    0
# Post Graduation YOP           0
# Current City                  0
# Final MOCK                    0
# Communication Remark          0
# TR                            0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2["10th Percentage"].sum()
# Out:
# 2180.27

# %%
df2["10th Percentage"].min()
# Out:
# 9.47

# %%
df2["10th Percentage"].max()
# Out:
# 94.2

# %%
df2["10th Percentage"].mean()
# Out:
# 58.92621621621622

# %%
df2["10th Percentage"].count()
# Out:
# 37

# %%
data={"Id":[1,2,3,2,5],"Name":["Afnan","Suyash","Aadesh","Suyash","Suresh"],"Marks":[21,22,23,22,25]}
df0 = pd.DataFrame(data)
df0
# Out:
#    Id    Name  Marks
# 0   1   Afnan     21
# 1   2  Suyash     22
# 2   3  Aadesh     23
# 3   2  Suyash     22
# 4   5  Suresh     25

# %%
df0.duplicated().sum()
# Out:
# 1

# %%
df12= df0.drop_duplicates()
df12
# Out:
#    Id    Name  Marks
# 0   1   Afnan     21
# 1   2  Suyash     22
# 2   3  Aadesh     23
# 4   5  Suresh     25
