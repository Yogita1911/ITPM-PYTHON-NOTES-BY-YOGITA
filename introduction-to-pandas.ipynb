# %%
## **Introduction to Pandas**

## **Understanding Series and DataFrame**

Pandas is a powerful open-source data analysis and manipulation library 
for Python. It is built on top of NumPy and provides high-level data 
structures and tools designed for practical and efficient data analysis.
Pandas is widely used in data science, machine learning, and 
data visualization projects due to its ease of use and versatility.


### **1. Series**
- A Series is a one-dimensional labeled array.
- Syntax: 
  pandas.Series(data, index=index)

- Key Characteristics:
  - Homogeneous data type.
  - Indexed like a dictionary for quick access.

### **2. DataFrame**
- A DataFrame is a two-dimensional labeled data structure with rows and columns.
- Syntax:
  
  pandas.DataFrame(data, index=index, columns=columns)
  
- Key Characteristics:
  - Columns can have different data types.
  - Offers functionalities for data manipulation, analysis, and visualization.

# %%
import pandas as pd

# %%
import pandas as pd
data = [1, 2, 3, 4, 5]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd
data = [1, 2, 3, 4, 5]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series)

# %%
data = [1, 2.4, 3.3,"abc", 5]
series = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series)

# %%
data = {
      'Name': ['Alice', 'Bob', 'Charlie'],
      'Age': [25, 30, 35],
      'City': ['New York', 'Los Angeles', 'Chicago']
  }
df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## **Creating DataFrames**
#
# ### **1. From Dictionaries**

# %%
import pandas as pd

# %%
data = {
      'Name': ['John', 'Anna', 'Peter'],
      'Age': [28, 24, 35],
      'Profession': ['Engineer', 'Doctor', 'Lawyer']
  }
print(data)
df = pd.DataFrame(data)
print(df)
# Out:
# {'Name': ['John', 'Anna', 'Peter'], 'Age': [28, 24, 35], 'Profession': ['Engineer', 'Doctor', 'Lawyer']}
#     Name  Age Profession
# 0   John   28   Engineer
# 1   Anna   24     Doctor
# 2  Peter   35     Lawyer

# %% [markdown]
# ### **2. From Arrays**

# %%
import numpy as np
data = np.array([[1, 2, 3], [4, 5, 6]])
df = pd.DataFrame(data, columns=['A', 'B', 'C'])
print(df)

# %% [markdown]
# ### Indexing in series:

# %%
data = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])

# Accessing by label
print(data['b'])  

# Accessing by position
print(data[2])
# Out:
# 20
# 30
# <ipython-input-7-c4fef679c469>:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(data[2])

# %% [markdown]
# ### Indexing in DataFrame

# %%
# Creating a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
# Accessing a column by label
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
# Accessing multiple columns
print(df[['Name', 'Age']])  # Outputs "Name" and "Age" columns
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
# Accessing a row using .loc (label-based)
print(df.loc[1])  # Row with index 1 (Bob)
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
# Accessing a row using .iloc (position-based)
print(df.iloc[2])  # Third row (Charlie)

# %% [markdown]
# #### slicing:

# %%
import pandas as pd

# Creating a Series
data = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])

# Slicing by position
print(data[1:4])  # Outputs 20,30,40

# Slicing by index label
print(data['b':'d'])  # Outputs 20,30,40

# Reverse slicing
print(data[::-1])  # Outputs elements in reverse order

# Slicing with step
print(data[::2])  # Every second element
# Out:
# b    20
# c    30
# d    40
# dtype: int64
# b    20
# c    30
# d    40
# dtype: int64
# e    50
# d    40
# c    30
# b    20
# a    10
# dtype: int64
# a    10
# c    30
# e    50
# dtype: int64

# %% [markdown]
# ### **3. From CSV Files**

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/home-loan-approval-train-dataset/loan_sanction_train.csv")
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.head(10)

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
df.tail(10)

# %%
df.shape
# Out:
# (614, 13)

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.rename(columns={'CoapplicantIncome': 'CA'}, inplace=True)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome      CA  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             5849     0.0         NaN             360.0             1.0
# 1             4583  1508.0       128.0             360.0             1.0
# 2             3000     0.0        66.0             360.0             1.0
# 3             2583  2358.0       120.0             360.0             1.0
# 4             6000     0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %%
df.drop(columns=['CA'], inplace=True)
#df.drop(index=[0, 1], inplace=True)  # Drop rows 0 and 1
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             5849         NaN             360.0             1.0
# 1             4583       128.0             360.0             1.0
# 2             3000        66.0             360.0             1.0
# 3             2583       120.0             360.0             1.0
# 4             6000       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Loan_ID           614 non-null    object
#  1   Gender            601 non-null    object
#  2   Married           611 non-null    object
#  3   Dependents        599 non-null    object
#  4   Education         614 non-null    object
#  5   Self_Employed     582 non-null    object
#  6   ApplicantIncome   614 non-null    int64
#  7   LoanAmount        592 non-null    float64
#  8   Loan_Amount_Term  600 non-null    float64
#  9   Credit_History    564 non-null    float64
#  10  Property_Area     614 non-null    object
#  11  Loan_Status       614 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 57.7+ KB

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_excel("/kaggle/input/model12/tensorflow2/default/1/Batch_report (13).xlsx")
df1
# Out:
#    Candidate Full Name                        Email ID  Contact No  \
# 0        Vikas  Ghadge          ghadgevikas8@gmail.com  9673714108
# 1        Kumail Mehter       kumail.mehter22@gmail.com  7875940600
# 2      Avantika Jadhav  avantikajadhav492003@gmail.com  9762074834
# 3     Chaitanya Sawant    sawantchaitanya592@gmail.com  7517918868
# 4         Nupur Pandya          nupurpandya8@gmail.com  8793348958
# 5       Kanchan Malode        kanchanmalode6@gmail.com  7756992407
# 6          Divya Borse         divyaborse252@gmail.com  9119554031
# 7           Isha Nikam         ishanikam1213@gmail.com  7378343080
# 8   Yadnyesh Chaudhari  yadnyeshchaudhari875@gmail.com  8766937956
# 9         Priya Kamble       priyakamble1308@gmail.com  9028416444
# 10        Mayur Sabgar          sabgarmayur7@gmail.com  7709748933
# 11    Snehal Sherikar         sherikarsnehal@gmail.com  7030216447
# 12        Akash Sonone        Akashsonone882@gmail.com  9022408741
# 13     Sakshi  Vidhate       sakshividhate05@gmail.com  8805409692
# 14     Sanjay Wankhade          wankhades198@gmail.com  9130342205
# 15      unesh sikarwar      yuneshsikarwar31@gmail.com  6232146871
# 16     Saksham Agrawal      agrawalsaksham02@gmail.com  7746970281
# 17       Mayur karande      mayurkarande0142@gmail.com  9284312750
#
#    Admission Date  Course Name                             Domain  \
# 0      20-09-2024         ITPD                     Data Analytics
# 1      20-09-2024         ITPD                     Data Analytics
# 2      20-09-2024          NaN                                NaN
# 3      20-09-2024          NaN                                NaN
# 4      20-09-2024  UPGRADATION                            Decided
# 5      20-07-2024         ITPD             Python Web Development
# 6      20-09-2024         ITPD                     Data Analytics
# 7      09-09-2024         ITPD             Python Web Development
# 8      04-09-2024         ITPD             Python Web Development
# 9      10-09-2024         ITPD  Business Analyst + Data Analytics
# 10     20-09-2024         ITPD                                NaN
# 11     20-09-2024         ITPD                     Data Analytics
# 12     25-01-2024         ITPD  Business Analyst + Data Analytics
# 13     20-09-2024         ITPD                     Data Analytics
# 14     07-08-2024         ITPD             Python Web Development
# 15     09-09-2024         ITPD             Python Web Development
# 16     09-09-2024         ITPD             Python Web Development
# 17     20-09-2024         ITPD                                NaN
#
#                              Skill Possessed  10th Percentage  10th YOP  \
# 0                              DataAnalytics            78.18    2011.0
# 1                              DataAnalytics            60.46    2009.0
# 2                                        NaN              NaN       NaN
# 3                                        NaN              NaN       NaN
# 4                           BusinessAnalysis            56.00    2007.0
# 5                                        Sql            80.60    2014.0
# 6                              C,C++,Java,UI            63.60    2019.0
# 7                                     Python            78.00    2018.0
# 8                                        Sql            62.80    2018.0
# 9                                        Sql            60.00    2009.0
# 10                                       NaN              NaN       NaN
# 11                                         C            73.40    2013.0
# 12  UI,Sql,DataAnalytics,Python,DataAnalysis            74.75    2009.0
# 13                      DataAnalytics,Python            84.00    2018.0
# 14                                    Python            69.45    2011.0
# 15                  Sql,DataAnalytics,Python             6.80    2017.0
# 16                             DataAnalytics            68.00    2018.0
# 17                                       NaN              NaN       NaN
#
#     12th Percentage  ...  Graduation YOP  Post Graduation  \
# 0             53.18  ...          2017.0              NaN
# 1             46.67  ...          2014.0              NaN
# 2               NaN  ...             NaN              NaN
# 3               NaN  ...             NaN              NaN
# 4             58.00  ...          2014.0            OTHER
# 5             59.08  ...          2019.0              NaN
# 6             73.00  ...          2024.0              NaN
# 7             57.00  ...          2024.0              NaN
# 8             66.00  ...          2024.0              NaN
# 9             54.00  ...          2014.0            OTHER
# 10              NaN  ...             NaN              NaN
# 11            69.40  ...          2019.0              NaN
# 12            54.50  ...          2017.0              NaN
# 13            71.00  ...          2024.0            OTHER
# 14            54.67  ...          2016.0              NaN
# 15              NaN  ...          2024.0              NaN
# 16            88.00  ...          2024.0              NaN
# 17              NaN  ...             NaN              NaN
#
#                      Post Graduation Percentage Post Graduation YOP  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4   Between 50% and 60% OR CGPA between 5 and 6              2014.0
# 5                                           NaN                 NaN
# 6                                           NaN                 NaN
# 7                                           NaN                 NaN
# 8                                           NaN                 NaN
# 9                     Above 60% OR CGPA above 6              2017.0
# 10                                          NaN                 NaN
# 11                                          NaN                 NaN
# 12                                          NaN                 NaN
# 13                                          NaN                 NaN
# 14                                          NaN                 NaN
# 15                                          NaN                 NaN
# 16                                          NaN                 NaN
# 17                                          NaN                 NaN
#
#    Current City                               Candidate Status Final MOCK  \
# 0          pune    Completed 80% Training & Final MOCK Pending    PENDING
# 1          pune    Completed 80% Training & Final MOCK Pending    PENDING
# 2           NaN                                    In Training    PENDING
# 3           NaN                           Training Not Started    PENDING
# 4          pune                           Training Not Started    PENDING
# 5         nasik  Completed 80% Training & Final MOCK Completed    PENDING
# 6       jalgaon                                    In Training    PENDING
# 7         nasik                                         Placed    PENDING
# 8       jalgaon    Completed 80% Training & Final MOCK Pending    PENDING
# 9          pune    Completed 80% Training & Final MOCK Pending    PENDING
# 10          NaN                           Training Not Started    PENDING
# 11     kolhapur  Completed 80% Training & Final MOCK Completed    PENDING
# 12         pune    Completed 80% Training & Final MOCK Pending    PENDING
# 13         pune                                    In Training    PENDING
# 14        akola    Completed 80% Training & Final MOCK Pending    PENDING
# 15        other    Completed 80% Training & Final MOCK Pending    PENDING
# 16        other                                    In Training    PENDING
# 17          NaN    Completed 80% Training & Final MOCK Pending    PENDING
#
#    Communication Remark  Technical Remark       Resume
# 0                  Good           Average  View Resume
# 1                  Good           Average  View Resume
# 2                  Poor              Poor          NaN
# 3                  Poor              Poor          NaN
# 4                  Poor              Poor  View Resume
# 5               Average           Average          NaN
# 6                  Poor              Poor  View Resume
# 7                  Good              Good  View Resume
# 8               Average              Good  View Resume
# 9                  Poor              Poor          NaN
# 10              PENDING               NaN          NaN
# 11                 Good              Good  View Resume
# 12              Average           Average          NaN
# 13                 Poor              Poor  View Resume
# 14                 Poor              Poor  View Resume
# 15              Average           Average  View Resume
# 16              Average              Good          NaN
# 17                 Poor              Poor          NaN
#
# [18 rows x 25 columns]
