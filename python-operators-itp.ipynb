# %% [markdown]
# ## Python divides the operators in the following groups:
#
# ### 1.Arithmetic operators
# ### 2.Comparison operators
# ### 3.Logical operators
# ### 4.Identity operators
# ### 5.Membership operators
# ### 6.Bitwise operators
# ### 7.Assignment operators

# %%
#1.Arithmatic operaters 
1.Addition (x + y)
2.Subtraction (x - y)
3.Multiplication(x * y)
4.Division(x / y)
5.Modulus(x % y)
6.Exponentiation(x ** y)

7.Floor division(x // y) # what is diff between / or //

# %%
#1.Arithmatic
x= 5
y= 3
print(x+y)         #add
print(x-y)         #sub
print(x*y)         #mul(5*3)
print(x**y)        #Expo = (x**y)=(5**3)=(5*5*5) = x=4,y=7=(4**7)=

print(x/y)         #div (Q) (int+float) (5/3)=1.66
print(x%y)         #modular div(R) (5/3) = 2
print(x//y)        #True or floor (Q only int) (5/3) = 1

# %%
x = 5
y = 2
print(x//y) #........5//2=2

# %%
2.Comparison operators

1.==Equal to (x==y)
2.!= Not equal (x != y)
3.> Greater than (x > y)
4.<	Less than (x < y)
5.>=Greater than or equal to (x >= y)# x==y or x>y True
6.<=Less than or equal to (x <= y) # x==y or x<y True

# %%
#2.Comparison
x=5
y=5
print(x==y) #1.Equalto

# %%
x=5
y=7
print(x!=y) #2.not Equalto

# %%
x=5
y=5
print(x!=y)

# %%
x=5
y=4
print(x>y)

# %%
x=5
y=4
print(x<y)

# %%
x=10
y=10
print(x>=y)

# %%
x=12
y=10
print(x>=y)

# %%
x=10
y=12
print(x<=y)

# %%
x=10
y=10
print(x<=y)

# %%
3.Logical operators

1.and 	Returns True if both statements are true	x < 5 and  x < 10	
2.or	Returns True if one of the statements is true	x < 5 or x < 4	
3.not	Reverse the result, returns False if the result is true	not(x < 5 and x < 10)

# %%
x =10
y = 7
print (x>5 and y>5)

# %%
x =10
y = 3
print (x>5 and y>5)

# %%
x =10
y = 3
print (x>5 or y>5)

# %%
x =10
y = 7
print (x>5 or y>5)

# %%
x =10
y = 3
print (not(x>5 or y>5))

# %%
x = 4
y = 4
print(x is y)
print(x is not y)

# %%
x = 4
y = 4
print(x is y)
print(x is not y)

# %%
4.Identity operators

1.is 	Returns True if both variables are the same 	x is y	
2.is not	Returns True if both variables are not the same 	x is not y

# %%
x = 5
y = 5
 #values
print(x is y)  # mem l

# %%
x = 5   
y = 10
 
print(x is y)

# %%
x = 5   
y = 10
 
print(x is not y)

# %%
5.Membership operators

1.in 	Returns True if a sequence with the specified value is present in the object	x in y	
2.not in	Returns True if a sequence with the specified value is not present in the object	x not in y

# %%
string ="apple orange "
has_apple = "apple" in string
print(has_apple)

# %%
l1 = [1,2,3,4,5]
has_3 = 3  in l1
print(has_3)

# %%
Itpm_python = "yash shubham prajakta raj janvi"
shubham_present = "shubham" in Itpm_python
print(shubham_present)

# %%
Itpm_python = "yash shubham prajakta raj janvi"
shubham_present = "shubham" not in Itpm_python
print(shubham_present)

# %%
Itpm_python = "yash shubham prajakta raj janvi"
komal_present = "komal"not in Itpm_python
print(komal_present)

# %%
6.Bitwise operators¶
1.& AND	Sets each bit to 1 if both bits are 1	x & y	
2.|	OR	Sets each bit to 1 if one of two bits is 1	x | y	
3.^	XOR	Sets each bit to 1 if only one of two bits is 1	x ^ y	
4.~	NOT	Inverts all the bits	~x	
5.<< Zero  fill left shift	Shift left by pushing zeros in from the right and let the leftmost bits fall off	x << 2	
6.>>Signed right shift	Shift right by pushing copies of the leftmost bit in from the left, and let the rightmost bits fall off	x >> 2

# %%
x = 1   # dec - bin = 01
y = 2   # dec - bin = 10
#------------------------------
# & ................= 00 bin - dec 0
print (x&y)
# Out:
# 0

# %%
x = 1   # dec - bin = 01
y = 2   # dec - bin = 10
#------------------------------
# | ................= 11 bin - dec 3
print (x|y)
# Out:
# 3

# %%
x = 3   # dec - bin = 11
y = 2   # dec - bin = 10
#------------------------------
# & ................= 10 bin - dec 0
print (x&y)
# Out:
# 2

# %%
x = 3   # dec - bin = 11
y = 2   # dec - bin = 10
#------------------------------
# & ................= 10 bin - dec 0
print (x|y)

# %%
x = 4  #dec4 = bin 
y = 6
print(x&y)

# %%
x=1 # 01
y=2 # 10
print(x & y)   # 01&10 =====00 ===0
print (x|y) # 11 == 3
print(x^y)
print(~x)
print(x|y)
print(x<<2)
print(x>>2)

# %%
x=4
y=4
print(x|y)
print(x^y)

# %%
x = 1 .........01
y=2............10 # or 01|10 
z=  ...........11

# %%
#7.Assignment operators
1. = 
2. += (increae) 
3. -= 
4. *=
5. /=
6. %=
7. //=
8 **=

# %%
x=5
print(x)

# %%
x = 5 
x += 1 # x = x+1 ,5+1=6
print(x)
# Out:
# 6

# %%
x = 5 
x += 5 # x = x+1 ,5+1=6
print(x)
# Out:
# 10

# %%
x=6
x -=1
print(x)
# Out:
# 5

# %%
x= 8
x -=2 #x=x-2
print(x)
# Out:
# 6

# %%
x=6
x *=2 
print(x)
# Out:
# 12

# %%
y=10
y /=5  # y=y-5
print(y)
# Out:
# 2.0

# %%
x = 10
x %=2
print(x)
# Out:
# 0

# %%
x = 11
x //=2
print(x)
# Out:
# 5

# %%
x = 4
x **=2
print(x)
# Out:
# 16
